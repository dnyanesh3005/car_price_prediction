# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\dnyan\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\dnyan\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\dnyan\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
# ...

# %%
df=pd.read_csv("cars_clus.csv")

# %%
df
# Out:
#        manufact    model   sales  resale  type  price  engine_s  horsepow  \
# 0         Acura  Integra  16.919  16.360     0  21.50       1.8       140
# 1         Acura       TL  39.384  19.875     0  28.40       3.2       225
# 2         Acura       RL   8.588  29.725     0  42.00       3.5       210
# 3          Audi       A4  20.397  22.255     0  23.99       1.8       150
# 4          Audi       A6  18.780  23.555     0  33.95       2.8       200
# ..          ...      ...     ...     ...   ...    ...       ...       ...
# 112  Volkswagen     Golf   9.761  11.425     0  14.90       2.0       115
# 113  Volkswagen    Jetta  83.721  13.240     0  16.70       2.0       115
# 114  Volkswagen   Passat  51.102  16.725     0  21.20       1.8       150
# 115  Volkswagen   Cabrio   9.569  16.575     0  19.99       2.0       115
# 116  Volkswagen      GTI   5.596  13.760     0  17.50       2.0       115
#
#      wheelbas  width  length  curb_wgt  fuel_cap   mpg  lnsales  partition
# ...

# %%
df.isna().sum()
# Out:
# manufact     0
# model        0
# sales        0
# resale       0
# type         0
# price        0
# engine_s     0
# horsepow     0
# wheelbas     0
# width        0
# length       0
# curb_wgt     0
# fuel_cap     0
# mpg          0
# lnsales      0
# partition    0
# dtype: int64

# %%
df.dtypes
# Out:
# manufact      object
# model         object
# sales        float64
# resale       float64
# type           int64
# price        float64
# engine_s     float64
# horsepow       int64
# wheelbas     float64
# width        float64
# length       float64
# curb_wgt     float64
# fuel_cap     float64
# mpg          float64
# lnsales      float64
# partition      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   manufact   117 non-null    object
#  1   model      117 non-null    object
#  2   sales      117 non-null    float64
#  3   resale     117 non-null    float64
#  4   type       117 non-null    int64
#  5   price      117 non-null    float64
#  6   engine_s   117 non-null    float64
#  7   horsepow   117 non-null    int64
#  8   wheelbas   117 non-null    float64
#  9   width      117 non-null    float64
#  10  length     117 non-null    float64
#  11  curb_wgt   117 non-null    float64
#  12  fuel_cap   117 non-null    float64
#  13  mpg        117 non-null    float64
#  14  lnsales    117 non-null    float64
#  15  partition  117 non-null    int64
# dtypes: float64(11), int64(3), object(2)
# memory usage: 14.8+ KB

# %%
df['type'].unique()
# Out:
# array([0, 1])

# %%
df.drop('partition',axis=1,inplace=True)

# %%
df
# Out:
#        manufact    model   sales  resale  type  price  engine_s  horsepow  \
# 0         Acura  Integra  16.919  16.360     0  21.50       1.8       140
# 1         Acura       TL  39.384  19.875     0  28.40       3.2       225
# 2         Acura       RL   8.588  29.725     0  42.00       3.5       210
# 3          Audi       A4  20.397  22.255     0  23.99       1.8       150
# 4          Audi       A6  18.780  23.555     0  33.95       2.8       200
# ..          ...      ...     ...     ...   ...    ...       ...       ...
# 112  Volkswagen     Golf   9.761  11.425     0  14.90       2.0       115
# 113  Volkswagen    Jetta  83.721  13.240     0  16.70       2.0       115
# 114  Volkswagen   Passat  51.102  16.725     0  21.20       1.8       150
# 115  Volkswagen   Cabrio   9.569  16.575     0  19.99       2.0       115
# 116  Volkswagen      GTI   5.596  13.760     0  17.50       2.0       115
#
#      wheelbas  width  length  curb_wgt  fuel_cap   mpg  lnsales
# ...

# %%
lb=LabelEncoder()
df['manufact']=lb.fit_transform(df['manufact'])

# %%
df['model']=lb.fit_transform(df['model'])

# %%
df
# Out:
#      manufact  model   sales  resale  type  price  engine_s  horsepow  \
# 0           0     62  16.919  16.360     0  21.50       1.8       140
# 1           0    107  39.384  19.875     0  28.40       3.2       225
# 2           0     88   8.588  29.725     0  42.00       3.5       210
# 3           1      4  20.397  22.255     0  23.99       1.8       150
# 4           1      5  18.780  23.555     0  33.95       2.8       200
# ..        ...    ...     ...     ...   ...    ...       ...       ...
# 112        25     56   9.761  11.425     0  14.90       2.0       115
# 113        25     63  83.721  13.240     0  16.70       2.0       115
# 114        25     82  51.102  16.725     0  21.20       1.8       150
# 115        25     19   9.569  16.575     0  19.99       2.0       115
# 116        25     54   5.596  13.760     0  17.50       2.0       115
#
#      wheelbas  width  length  curb_wgt  fuel_cap   mpg  lnsales
# ...

# %%
corr=df.corr()
corr
# Out:
#           manufact     model     sales    resale      type     price  \
# manufact  1.000000  0.014121 -0.108854  0.007008  0.065339 -0.059690
# model     0.014121  1.000000  0.007472 -0.135488  0.235982 -0.080587
# sales    -0.108854  0.007472  1.000000 -0.275426  0.278774 -0.251705
# resale    0.007008 -0.135488 -0.275426  1.000000 -0.091679  0.954757
# type      0.065339  0.235982  0.278774 -0.091679  1.000000 -0.076303
# price    -0.059690 -0.080587 -0.251705  0.954757 -0.076303  1.000000
# engine_s -0.198276  0.104268  0.038111  0.527187  0.182515  0.649170
# horsepow -0.204274 -0.034658 -0.152538  0.773110 -0.045867  0.853455
# wheelbas -0.287358  0.148159  0.406839 -0.053685  0.385062  0.067042
# width    -0.278857  0.131421  0.177802  0.178128  0.220744  0.301292
# length   -0.310028  0.085267  0.272336  0.025390  0.109779  0.182592
# curb_wgt -0.176264  0.095054  0.067184  0.363274  0.469247  0.511400
# fuel_cap -0.152296  0.123186  0.138045  0.324796  0.586927  0.406496
# ...

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
x=df.drop(['price', 'manufact', 'model'],axis=1)
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([23.47938884, 15.23359294, 42.42672171, 13.03789661, 32.65969599,
#        52.47161205, 12.41152432, 31.84389439, 17.11785074, 41.11340081,
#        13.83220637, 16.18726437, 12.79232488, 19.1949142 , 19.56095015,
#        18.06036284, 18.98400214, 18.02717455, 13.23992164, 34.20965027,
#        11.00862056, 14.58849067, 29.86866023, 33.56653755])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mea=mean_squared_error(y_test,y_pred)
mea
# Out:
# 9.958432322445246

# %%
r2=r2_score(y_test,y_pred)
print(f"accuracy of model:{r2*100}%")
# Out:
# accuracy of model:92.74881805796657%

# %%
mae=mean_absolute_error(y_test,y_pred)
mae
# Out:
# 2.255518837495356

# %%
model.predict(x_test)
# Out:
# array([23.47938884, 15.23359294, 42.42672171, 13.03789661, 32.65969599,
#        52.47161205, 12.41152432, 31.84389439, 17.11785074, 41.11340081,
#        13.83220637, 16.18726437, 12.79232488, 19.1949142 , 19.56095015,
#        18.06036284, 18.98400214, 18.02717455, 13.23992164, 34.20965027,
#        11.00862056, 14.58849067, 29.86866023, 33.56653755])

# %%
x=df.drop(['price', 'manufact', 'model'],axis=1)
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

# %%
x=df.drop(['price', 'manufact', 'model'],axis=1)
y=df['price']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

class car:
    def __init__(self,x_train,y_train):
        self.x_train=x_train
        self.y_train=y_train
        self.model=None
    def model_trained(self):
        self.model=LinearRegression()
        self.model.fit(self.x_train,self.y_train)
    def price(self,x_test):
        prices=model.predict(x_test)
        print(f'price of cars:{prices}lakh')
        

        
c=car(x_train,y_train)
c.model_trained()
c.price(x_test)
# Out:
# price of cars:[23.47938884 15.23359294 42.42672171 13.03789661 32.65969599 52.47161205
#  12.41152432 31.84389439 17.11785074 41.11340081 13.83220637 16.18726437
#  12.79232488 19.1949142  19.56095015 18.06036284 18.98400214 18.02717455
#  13.23992164 34.20965027 11.00862056 14.58849067 29.86866023 33.56653755]lakh

# %%
import joblib

# Save model
joblib.dump(c.model, 'car_price_model.pkl')
# Out:
# ['car_price_model.pkl']
